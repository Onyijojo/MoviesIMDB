# %%
# Import important libraries
# !pip install requests bs4 selenium webdriver-manager pandas sqlalchemy psycopg2-binary ipython-sql prettytable==3.9.0
# Out:
# Collecting requests
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting bs4
#   Using cached bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting selenium
#   Downloading selenium-4.38.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting webdriver-manager
#   Using cached webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# Collecting pandas
#   Using cached pandas-2.3.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting sqlalchemy
#   Using cached sqlalchemy-2.0.44-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Collecting psycopg2-binary
#   Using cached psycopg2_binary-2.9.11-cp313-cp313-win_amd64.whl.metadata (5.1 kB)
# Collecting ipython-sql
#   Using cached ipython_sql-0.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting prettytable==3.9.0
#   Using cached prettytable-3.9.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: wcwidth in c:\users\admin\onedrive\documents\10alytics_training\movies\moviesimdb\.venv\lib\site-packages (from prettytable==3.9.0) (0.2.14)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Using cached charset_normalizer-3.4.4-cp313-cp313-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting beautifulsoup4 (from bs4)
#   Using cached beautifulsoup4-4.14.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting trio<1.0,>=0.31.0 (from selenium)
#   Downloading trio-0.32.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium)
#   Using cached trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting typing_extensions<5.0,>=4.15.0 (from selenium)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting websocket-client<2.0,>=1.8.0 (from selenium)
#   Using cached websocket_client-1.9.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting attrs>=23.2.0 (from trio<1.0,>=0.31.0->selenium)
#   Using cached attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting sortedcontainers (from trio<1.0,>=0.31.0->selenium)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium)
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting sniffio>=1.3.0 (from trio<1.0,>=0.31.0->selenium)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting cffi>=1.14 (from trio<1.0,>=0.31.0->selenium)
#   Using cached cffi-2.0.0-cp313-cp313-win_amd64.whl.metadata (2.6 kB)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium)
#   Using cached wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3.0,>=2.5.0->selenium)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Collecting python-dotenv (from webdriver-manager)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: packaging in c:\users\admin\onedrive\documents\10alytics_training\movies\moviesimdb\.venv\lib\site-packages (from webdriver-manager) (25.0)
# Collecting numpy>=1.26.0 (from pandas)
#   Using cached numpy-2.3.4-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\onedrive\documents\10alytics_training\movies\moviesimdb\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting greenlet>=1 (from sqlalchemy)
#   Using cached greenlet-3.2.4-cp313-cp313-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: ipython in c:\users\admin\onedrive\documents\10alytics_training\movies\moviesimdb\.venv\lib\site-packages (from ipython-sql) (9.6.0)
# Collecting sqlparse (from ipython-sql)
#   Using cached sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: six in c:\users\admin\onedrive\documents\10alytics_training\movies\moviesimdb\.venv\lib\site-packages (from ipython-sql) (1.17.0)
# Collecting ipython-genutils (from ipython-sql)
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Collecting pycparser (from cffi>=1.14->trio<1.0,>=0.31.0->selenium)
#   Using cached pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->bs4)
#   Using cached soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: colorama in c:\users\admin\onedrive\documents\10alytics_training\movies\moviesimdb\.venv\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator in c:\users\admin\onedrive\documents\10alytics_training\movies\moviesimdb\.venv\lib\site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\admin\onedrive\documents\10alytics_training\movies\moviesimdb\.venv\lib\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\admin\onedrive\documents\10alytics_training\movies\moviesimdb\.venv\lib\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\admin\onedrive\documents\10alytics_training\movies\moviesimdb\.venv\lib\site-packages (from ipython->ipython-sql) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\admin\onedrive\documents\10alytics_training\movies\moviesimdb\.venv\lib\site-packages (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\admin\onedrive\documents\10alytics_training\movies\moviesimdb\.venv\lib\site-packages (from ipython->ipython-sql) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\admin\onedrive\documents\10alytics_training\movies\moviesimdb\.venv\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\admin\onedrive\documents\10alytics_training\movies\moviesimdb\.venv\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\admin\onedrive\documents\10alytics_training\movies\moviesimdb\.venv\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\admin\onedrive\documents\10alytics_training\movies\moviesimdb\.venv\lib\site-packages (from stack_data->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\admin\onedrive\documents\10alytics_training\movies\moviesimdb\.venv\lib\site-packages (from stack_data->ipython->ipython-sql) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\admin\onedrive\documents\10alytics_training\movies\moviesimdb\.venv\lib\site-packages (from stack_data->ipython->ipython-sql) (0.2.3)
# Using cached prettytable-3.9.0-py3-none-any.whl (27 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp313-cp313-win_amd64.whl (107 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading selenium-4.38.0-py3-none-any.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 542.9 kB/s eta 0:00:17
#    -- ------------------------------------- 0.5/9.7 MB 542.9 kB/s eta 0:00:17
#    --- ------------------------------------ 0.8/9.7 MB 556.3 kB/s eta 0:00:17
#    ---- ----------------------------------- 1.0/9.7 MB 687.4 kB/s eta 0:00:13
#    ----- ---------------------------------- 1.3/9.7 MB 739.9 kB/s eta 0:00:12
#    ------ --------------------------------- 1.6/9.7 MB 817.6 kB/s eta 0:00:10
#    ------ --------------------------------- 1.6/9.7 MB 817.6 kB/s eta 0:00:10
#    ------- -------------------------------- 1.8/9.7 MB 808.8 kB/s eta 0:00:10
#    -------- ------------------------------- 2.1/9.7 MB 798.0 kB/s eta 0:00:10
#    -------- ------------------------------- 2.1/9.7 MB 798.0 kB/s eta 0:00:10
#    --------- ------------------------------ 2.4/9.7 MB 787.5 kB/s eta 0:00:10
#    --------- ------------------------------ 2.4/9.7 MB 787.5 kB/s eta 0:00:10
#    ----------- ---------------------------- 2.9/9.7 MB 833.6 kB/s eta 0:00:09
#    ----------- ---------------------------- 2.9/9.7 MB 833.6 kB/s eta 0:00:09
#    ------------ --------------------------- 3.1/9.7 MB 817.5 kB/s eta 0:00:09
#    ---------------- ----------------------- 3.9/9.7 MB 957.3 kB/s eta 0:00:07
#    ------------------ --------------------- 4.5/9.7 MB 1.1 MB/s eta 0:00:05
#    --------------------- ------------------ 5.2/9.7 MB 1.2 MB/s eta 0:00:04
#    ---------------------- ----------------- 5.5/9.7 MB 1.2 MB/s eta 0:00:04
#    ------------------------ --------------- 6.0/9.7 MB 1.2 MB/s eta 0:00:03
#    ------------------------- -------------- 6.3/9.7 MB 1.2 MB/s eta 0:00:03
#    --------------------------- ------------ 6.6/9.7 MB 1.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 6.8/9.7 MB 1.3 MB/s eta 0:00:03
#    ------------------------------ --------- 7.3/9.7 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 8.1/9.7 MB 1.4 MB/s eta 0:00:02
#    ------------------------------------- -- 9.2/9.7 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.7 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 1.5 MB/s  0:00:06
# Downloading trio-0.32.0-py3-none-any.whl (512 kB)
# Using cached trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached websocket_client-1.9.0-py3-none-any.whl (82 kB)
# Using cached webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Using cached pandas-2.3.3-cp313-cp313-win_amd64.whl (11.0 MB)
# Using cached sqlalchemy-2.0.44-cp313-cp313-win_amd64.whl (2.1 MB)
# Using cached psycopg2_binary-2.9.11-cp313-cp313-win_amd64.whl (2.7 MB)
# Using cached ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Using cached attrs-25.4.0-py3-none-any.whl (67 kB)
# Using cached certifi-2025.10.5-py3-none-any.whl (163 kB)
# Using cached cffi-2.0.0-cp313-cp313-win_amd64.whl (183 kB)
# Using cached greenlet-3.2.4-cp313-cp313-win_amd64.whl (299 kB)
# Using cached numpy-2.3.4-cp313-cp313-win_amd64.whl (12.8 MB)
# Using cached outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached beautifulsoup4-4.14.2-py3-none-any.whl (106 kB)
# Using cached soupsieve-2.8-py3-none-any.whl (36 kB)
# Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Using cached pycparser-2.23-py3-none-any.whl (118 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Using cached sqlparse-0.5.3-py3-none-any.whl (44 kB)
# Installing collected packages: sortedcontainers, pytz, ipython-genutils, websocket-client, urllib3, tzdata, typing_extensions, sqlparse, soupsieve, sniffio, python-dotenv, pysocks, pycparser, psycopg2-binary, prettytable, numpy, idna, h11, greenlet, charset_normalizer, certifi, attrs, wsproto, sqlalchemy, requests, pandas, outcome, cffi, beautifulsoup4, webdriver-manager, trio, ipython-sql, bs4, trio-websocket, selenium
#
#    ----------------------------------------  0/35 [sortedcontainers]
#    - --------------------------------------  1/35 [pytz]
#    - --------------------------------------  1/35 [pytz]
#    - --------------------------------------  1/35 [pytz]
#    - --------------------------------------  1/35 [pytz]
#    - --------------------------------------  1/35 [pytz]
#    - --------------------------------------  1/35 [pytz]
#    - --------------------------------------  1/35 [pytz]
#    - --------------------------------------  1/35 [pytz]
#    - --------------------------------------  1/35 [pytz]
#    - --------------------------------------  1/35 [pytz]
#    - --------------------------------------  1/35 [pytz]
#    - --------------------------------------  1/35 [pytz]
#    - --------------------------------------  1/35 [pytz]
#    - --------------------------------------  1/35 [pytz]
#    - --------------------------------------  1/35 [pytz]
#    - --------------------------------------  1/35 [pytz]
#    - --------------------------------------  1/35 [pytz]
#    - --------------------------------------  1/35 [pytz]
#    - --------------------------------------  1/35 [pytz]
#    -- -------------------------------------  2/35 [ipython-genutils]
#    -- -------------------------------------  2/35 [ipython-genutils]
#    -- -------------------------------------  2/35 [ipython-genutils]
#    -- -------------------------------------  2/35 [ipython-genutils]
#    --- ------------------------------------  3/35 [websocket-client]
#    --- ------------------------------------  3/35 [websocket-client]
#    --- ------------------------------------  3/35 [websocket-client]
#    --- ------------------------------------  3/35 [websocket-client]
#    --- ------------------------------------  3/35 [websocket-client]
#    --- ------------------------------------  3/35 [websocket-client]
#    --- ------------------------------------  3/35 [websocket-client]
#    --- ------------------------------------  3/35 [websocket-client]
#    --- ------------------------------------  3/35 [websocket-client]
#    --- ------------------------------------  3/35 [websocket-client]
#    --- ------------------------------------  3/35 [websocket-client]
#    --- ------------------------------------  3/35 [websocket-client]
#    ---- -----------------------------------  4/35 [urllib3]
#    ---- -----------------------------------  4/35 [urllib3]
#    ---- -----------------------------------  4/35 [urllib3]
#    ---- -----------------------------------  4/35 [urllib3]
#    ---- -----------------------------------  4/35 [urllib3]
#    ---- -----------------------------------  4/35 [urllib3]
#    ---- -----------------------------------  4/35 [urllib3]
#    ---- -----------------------------------  4/35 [urllib3]
#    ---- -----------------------------------  4/35 [urllib3]
#    ---- -----------------------------------  4/35 [urllib3]
#    ---- -----------------------------------  4/35 [urllib3]
#    ----- ----------------------------------  5/35 [tzdata]
#    ----- ----------------------------------  5/35 [tzdata]
#    ----- ----------------------------------  5/35 [tzdata]
#    ----- ----------------------------------  5/35 [tzdata]
#    ----- ----------------------------------  5/35 [tzdata]
#    ----- ----------------------------------  5/35 [tzdata]
#    ----- ----------------------------------  5/35 [tzdata]
#    ----- ----------------------------------  5/35 [tzdata]
#    ------ ---------------------------------  6/35 [typing_extensions]
#    -------- -------------------------------  7/35 [sqlparse]
#    -------- -------------------------------  7/35 [sqlparse]
#    -------- -------------------------------  7/35 [sqlparse]
#    -------- -------------------------------  7/35 [sqlparse]
#    -------- -------------------------------  7/35 [sqlparse]
#    -------- -------------------------------  7/35 [sqlparse]
#    -------- -------------------------------  7/35 [sqlparse]
#    -------- -------------------------------  7/35 [sqlparse]
#    -------- -------------------------------  7/35 [sqlparse]
#    --------- ------------------------------  8/35 [soupsieve]
#    --------- ------------------------------  8/35 [soupsieve]
#    --------- ------------------------------  8/35 [soupsieve]
#    ---------- -----------------------------  9/35 [sniffio]
#    ----------- ---------------------------- 10/35 [python-dotenv]
#    ----------- ---------------------------- 10/35 [python-dotenv]
#    ----------- ---------------------------- 10/35 [python-dotenv]
#    ----------- ---------------------------- 10/35 [python-dotenv]
#    ------------ --------------------------- 11/35 [pysocks]
#    ------------- -------------------------- 12/35 [pycparser]
#    ------------- -------------------------- 12/35 [pycparser]
#    ------------- -------------------------- 12/35 [pycparser]
#    ------------- -------------------------- 12/35 [pycparser]
#    ------------- -------------------------- 12/35 [pycparser]
#    ------------- -------------------------- 12/35 [pycparser]
#    -------------- ------------------------- 13/35 [psycopg2-binary]
#    -------------- ------------------------- 13/35 [psycopg2-binary]
#    -------------- ------------------------- 13/35 [psycopg2-binary]
#    ---------------- ----------------------- 14/35 [prettytable]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ----------------- ---------------------- 15/35 [numpy]
#    ------------------ --------------------- 16/35 [idna]
#    ------------------ --------------------- 16/35 [idna]
#    ------------------ --------------------- 16/35 [idna]
#    ------------------ --------------------- 16/35 [idna]
#    ------------------- -------------------- 17/35 [h11]
#    ------------------- -------------------- 17/35 [h11]
#    ------------------- -------------------- 17/35 [h11]
#    ------------------- -------------------- 17/35 [h11]
#    ------------------- -------------------- 17/35 [h11]
#    -------------------- ------------------- 18/35 [greenlet]
#    -------------------- ------------------- 18/35 [greenlet]
#    -------------------- ------------------- 18/35 [greenlet]
#    -------------------- ------------------- 18/35 [greenlet]
#    -------------------- ------------------- 18/35 [greenlet]
#    -------------------- ------------------- 18/35 [greenlet]
#    --------------------- ------------------ 19/35 [charset_normalizer]
#    --------------------- ------------------ 19/35 [charset_normalizer]
#    --------------------- ------------------ 19/35 [charset_normalizer]
#    --------------------- ------------------ 19/35 [charset_normalizer]
#    --------------------- ------------------ 19/35 [charset_normalizer]
#    ---------------------- ----------------- 20/35 [certifi]
#    ------------------------ --------------- 21/35 [attrs]
#    ------------------------ --------------- 21/35 [attrs]
#    ------------------------ --------------- 21/35 [attrs]
#    ------------------------ --------------- 21/35 [attrs]
#    ------------------------ --------------- 21/35 [attrs]
#    ------------------------- -------------- 22/35 [wsproto]
#    ------------------------- -------------- 22/35 [wsproto]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    -------------------------- ------------- 23/35 [sqlalchemy]
#    --------------------------- ------------ 24/35 [requests]
#    --------------------------- ------------ 24/35 [requests]
#    --------------------------- ------------ 24/35 [requests]
#    --------------------------- ------------ 24/35 [requests]
#    --------------------------- ------------ 24/35 [requests]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
# ...
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ---------------------------- ----------- 25/35 [pandas]
#    ------------------------------ --------- 27/35 [cffi]
#    ------------------------------ --------- 27/35 [cffi]
#    ------------------------------ --------- 27/35 [cffi]
#    ------------------------------ --------- 27/35 [cffi]
#    ------------------------------ --------- 27/35 [cffi]
#    ------------------------------ --------- 27/35 [cffi]
#    -------------------------------- ------- 28/35 [beautifulsoup4]
#    -------------------------------- ------- 28/35 [beautifulsoup4]
#    -------------------------------- ------- 28/35 [beautifulsoup4]
#    -------------------------------- ------- 28/35 [beautifulsoup4]
#    -------------------------------- ------- 28/35 [beautifulsoup4]
#    -------------------------------- ------- 28/35 [beautifulsoup4]
#    --------------------------------- ------ 29/35 [webdriver-manager]
#    --------------------------------- ------ 29/35 [webdriver-manager]
#    --------------------------------- ------ 29/35 [webdriver-manager]
#    --------------------------------- ------ 29/35 [webdriver-manager]
#    --------------------------------- ------ 29/35 [webdriver-manager]
#    --------------------------------- ------ 29/35 [webdriver-manager]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ---------------------------------- ----- 30/35 [trio]
#    ----------------------------------- ---- 31/35 [ipython-sql]
#    ----------------------------------- ---- 31/35 [ipython-sql]
#    ----------------------------------- ---- 31/35 [ipython-sql]
#    ------------------------------------- -- 33/35 [trio-websocket]
#    ------------------------------------- -- 33/35 [trio-websocket]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    -------------------------------------- - 34/35 [selenium]
#    ---------------------------------------- 35/35 [selenium]
#
# Successfully installed attrs-25.4.0 beautifulsoup4-4.14.2 bs4-0.0.2 certifi-2025.10.5 cffi-2.0.0 charset_normalizer-3.4.4 greenlet-3.2.4 h11-0.16.0 idna-3.11 ipython-genutils-0.2.0 ipython-sql-0.5.0 numpy-2.3.4 outcome-1.3.0.post0 pandas-2.3.3 prettytable-3.9.0 psycopg2-binary-2.9.11 pycparser-2.23 pysocks-1.7.1 python-dotenv-1.2.1 pytz-2025.2 requests-2.32.5 selenium-4.38.0 sniffio-1.3.1 sortedcontainers-2.4.0 soupsieve-2.8 sqlalchemy-2.0.44 sqlparse-0.5.3 trio-0.32.0 trio-websocket-0.12.2 typing_extensions-4.15.0 tzdata-2025.2 urllib3-2.5.0 webdriver-manager-4.0.2 websocket-client-1.9.0 wsproto-1.2.0

# %%
# Import required libraries
import pandas as pd
from sqlalchemy import create_engine
import requests
from bs4 import BeautifulSoup
import psycopg2

# %%
# Define the target URL (IMDb Top 250 Movies page)
url = "https://www.imdb.com/chart/top/"

# Define custom headers to mimic a browser request
headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

# Parse the HTML content of the page using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Create an empty list to store movie titles
movie_titles = []

# Find all title div elements using IMDb's current CSS class
titles = soup.find_all(
    "div",
    class_="ipc-title ipc-title--base ipc-title--title ipc-title--title--reduced ipc-title-link-no-icon ipc-title--on-textPrimary sc-87337ed2-2 dRlLYG cli-title with-margin"
)

# Loop through the first 20 movie titles and extract text
for t in titles[:20]:
    movie_titles.append(t.get_text(strip=True))

# Display extracted titles
print(movie_titles)
# Out:
# ['The Shawshank Redemption', 'The Godfather', 'The Dark Knight', 'The Godfather Part II', '12 Angry Men', 'The Lord of the Rings: The Return of the King', "Schindler's List", 'The Lord of the Rings: The Fellowship of the Ring', 'Pulp Fiction', 'The Good, the Bad and the Ugly', 'The Lord of the Rings: The Two Towers', 'Forrest Gump', 'Fight Club', 'Inception', 'Star Wars: Episode V - The Empire Strikes Back', 'The Matrix', 'GoodFellas', 'Interstellar', "One Flew Over the Cuckoo's Nest", 'Seven']

# %%
# Create an empty list to store movie release years
movie_years = []

# Find all 'div' elements that contain the movie year
year_elements = soup.find_all(
    "div",
    class_="sc-caa65599-6 hhUutV cli-title-metadata"
)

# Loop through the first 20 elements and extract the year
for y in year_elements[:20]:
    text = y.get_text(strip=True)
    release_year = text[:4]  # Extract the first 4 characters (the year)
    movie_years.append(release_year)

# Display the extracted years
print(movie_years)
# Out:
# ['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2001', '1994', '1966', '2002', '1994', '1999', '2010', '1980', '1999', '1990', '2014', '1975', '1995']

# %%
# Create an empty list to store IMDb ratings
movie_ratings = []

# Find all span elements containing the movie ratings
rating_elements = soup.find_all("span", class_="ipc-rating-star--rating")

# Loop through the first 20 ratings and extract text
for r in rating_elements[:20]:
    rating_value = r.get_text(strip=True)
    movie_ratings.append(rating_value)

# Display extracted ratings
print(movie_ratings)
# Out:
# ['9.3', '9.2', '9.1', '9.0', '9.0', '9.0', '9.0', '8.9', '8.8', '8.8', '8.8', '8.8', '8.8', '8.8', '8.7', '8.7', '8.7', '8.7', '8.6', '8.6']

# %%
# Combine scraped lists into a dictionary
movies_data = {
    "title": movie_titles,
    "year": movie_years,
    "rating": movie_ratings
}

# Convert the dictionary into a pandas DataFrame
movie_df = pd.DataFrame(movies_data)

# Display the DataFrame
print("IMDb Top 20 Movies:")
display(movie_df.head())
# Out:
# IMDb Top 20 Movies:
#                       title  year rating
# 0  The Shawshank Redemption  1994    9.3
# 1             The Godfather  1972    9.2
# 2           The Dark Knight  2008    9.1
# 3     The Godfather Part II  1974    9.0
# 4              12 Angry Men  1957    9.0

# %% [markdown]
# #### Data Cleaning

# %%
# Convert 'movie_year' to numeric (integer)
movie_df["year"] = pd.to_numeric(movie_df["year"], errors="coerce").astype("Int64")

# Convert 'movie_rating' to float
movie_df["rating"] = pd.to_numeric(movie_df["rating"], errors="coerce").astype(float)

# Display the cleaned DataFrame
print("Cleaned and formatted:")
display(movie_df)
# Out:
# Cleaned and formatted:
#                                                 title  year  rating
# 0                            The Shawshank Redemption  1994     9.3
# 1                                       The Godfather  1972     9.2
# 2                                     The Dark Knight  2008     9.1
# 3                               The Godfather Part II  1974     9.0
# 4                                        12 Angry Men  1957     9.0
# 5       The Lord of the Rings: The Return of the King  2003     9.0
# 6                                    Schindler's List  1993     9.0
# 7   The Lord of the Rings: The Fellowship of the Ring  2001     8.9
# 8                                        Pulp Fiction  1994     8.8
# 9                      The Good, the Bad and the Ugly  1966     8.8
# 10              The Lord of the Rings: The Two Towers  2002     8.8
# 11                                       Forrest Gump  1994     8.8
# 12                                         Fight Club  1999     8.8
# 13                                          Inception  2010     8.8
# 14     Star Wars: Episode V - The Empire Strikes Back  1980     8.7
# 15                                         The Matrix  1999     8.7
# 16                                         GoodFellas  1990     8.7
# 17                                       Interstellar  2014     8.7
# 18                    One Flew Over the Cuckoo's Nest  1975     8.6
# 19                                              Seven  1995     8.6

# %%
# Keep only the relevant columns
movie_df = movie_df[["title", "year", "rating"]]

# Create a sequential ID starting from 1
movie_df["ID"] = range(1, len(movie_df) + 1)

# Reorder columns so ID appears first
movie_df = movie_df[["ID", "title", "year", "rating"]]

# Display the updated DataFrame
print("Final cleaned:")
display(movie_df.head())
# Out:
# Final cleaned:
#    ID                     title  year  rating
# 0   1  The Shawshank Redemption  1994     9.3
# 1   2             The Godfather  1972     9.2
# 2   3           The Dark Knight  2008     9.1
# 3   4     The Godfather Part II  1974     9.0
# 4   5              12 Angry Men  1957     9.0

# %%
# Exporting to CSV
output_path = r"cleaned_data\movies.csv"

# Save the cleaned data to a CSV file
movie_df.to_csv(output_path, index=False)

print(f"Data successfully saved to: {output_path}")
# Out:
# Data successfully saved to: cleaned_data\movies.csv

# %%
# Import SQLAlchemy library
from sqlalchemy import create_engine

# Define PostgreSQL database connection parameters 
db_name = "movies_IMDb"
db_host = "localhost"
db_user = "postgres"
db_password = "London123"
db_port = "5432"

# %%
# Create SQLAlchemy engine
engine = create_engine(
    f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}'
)

# %%
# Load DataFrames to PostgreSQL table
movie_df.to_sql('movies', engine, index=False, if_exists='replace')


print("Table loaded successfully to PostgreSQL.")
# Out:
# Table loaded successfully to PostgreSQL.
